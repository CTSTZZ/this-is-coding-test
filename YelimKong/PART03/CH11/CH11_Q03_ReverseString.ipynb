# %% [markdown]
# ### Q3.  문자열 뒤집기

# %% [markdown]
# 0과 1로 이루어진 문자열 S가 있다. 문자열 S에 있는 모든 숫자를 전부 같게 만들려고 한다. S에서 연속된 하나 이상의 숫자를 잡고 모두 뒤집는 것. **뒤집는 것은 1을 0으로, 0을 1로 바꾸는 것을 의미**

# %% [markdown]
# 예를 들어 S = 0001100 일 때는
#
#     1. 전체를 뒤집으면 1110011이 된다.
#     2. 4번째 문자부터 5번째 문자까지 뒤집으면 11111111이 되어서 두 번 만에 모두 같은 숫자로 만들 수 있다.
#
# 하지만, 처음부터 4번째 문자부터 5번째 문자까지 뒤집으면 한 번에 00000000이 되어서 1번 만에 모두 같은 숫자로 만들 수 있다.
#
# 문자열 S가 주어졌을 때, **해야 하는 행동의 최소 횟수를 출력하시오**

# %% [markdown]
# **입력 조건**
# * 첫째 줄에 0과 1로만 이루어진 문자열 S가 주어진다. S의 길이는 100만보다 작다.

# %% [markdown]
# **출력 조건**
# * 첫째 줄에 해야하는 행동의 최소 횟수 출력

# %%
import time 

# 1. 문자열 입력받는다. 
S = input()

start_time = time.time()  # 시작 시간 

# 2. 최소 횟수 세기 0으로 초기화  
count = 0 

# 3. 문자열 S가 0 또는 1로 이루어져 있는지 확인
if set(S) != {'0', '1'}:
    print("0 또는 1만 입력 가능합니다.")
else:
    for i in range(len(S) - 1):
        # 4. 현재 문자와 다음 문자가 다를 경우 count 증가
        if S[i] != S[i + 1]:
            count += 1

# 5. 최종 결과 계산
# 1) count + 1 : 전체 뒤집기 계산 
# 2) (count + 1) // 2 : 한 번에 중간에 있는 숫자를 뒤집는 조건 반영 
result = (count + 1) // 2

end_time = time.time()  # 종료 시간 

# 실행 시간 출력
running_time = end_time - start_time
print(f"실행 시간: {running_time} 초")

# 결과 출력
print(result)
# Out:
# 00011000
# 실행 시간: 0.0010008811950683594 초
# 1

# %%
import time 

# 1. 문자열 입력받는다. 
S = input()

start_time = time.time()  # 시작 시간 

# 2. 최소 횟수 세기 0으로 초기화  
count = 0 

# 3. 문자열 S가 0 또는 1로 이루어져 있는지 확인
if set(S) != {'0', '1'}:
    print("0 또는 1만 입력 가능합니다.")
else:
    for i in range(len(S) - 1):
        # 4. 현재 문자와 다음 문자가 다를 경우 count 증가
        if S[i] != S[i + 1]:
            count += 1

# 5. 최종 결과 계산
# 1) count + 1 : 전체 뒤집기 계산 
# 2) (count + 1) // 2 : 한 번에 중간에 있는 숫자를 뒤집는 조건 반영 
result = (count + 1) // 2

end_time = time.time()  # 종료 시간 

# 실행 시간 출력
running_time = end_time - start_time
print(f"실행 시간: {running_time} 초")

# 결과 출력
print(result)
# Out:
# 10110001
# 실행 시간: 0.0010023117065429688 초
# 2

# %% [markdown]
# ![q3.jpg](attachment:q3.jpg)
