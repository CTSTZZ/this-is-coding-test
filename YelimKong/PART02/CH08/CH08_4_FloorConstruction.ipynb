# %% [markdown]
# ### **CH08 다이나믹 프로그래밍**

# %% [markdown]
# ### **(4) 바닥 공사**

# %% [markdown]
# 가로의 길이가 N, 세로의 길이가 2인 직사각형 형태의 얇은 바닥이 있다. 이 야얇은 바닥을 1 X 2의 덮개, 2 X 1 의 덮개, 2 X 2의 덮개를 이용해 채우고자 한다.

# %% [markdown]
# ![ch8-4.png](attachment:ch8-4.png)

# %% [markdown]
# 이때 바닥을 채우는 모든 경우의 수를 구하는 프로그램 작성하시오. 예를 들어 2 X 3 크기의 바닥을 채우는 경우의 수는 5가지이다.

# %% [markdown]
# **입력 조건**

# %% [markdown]
# * 첫째 줄에 N이 주어진다. (1 ≤ N ≤ 1,000)

# %% [markdown]
# **출력 조건**

# %% [markdown]
# * 첫째 줄에 2 X N크기의 바닥을 채우는 방법의 수를 796,796 으로 나눈 나머지를 출력한다.

# %% [markdown]
# **입력 예시**

# %% [markdown]
# 3

# %% [markdown]
# **출력 예시**

# %% [markdown]
# 5

# %% [markdown]
# **코드(정답)**

# %%
n = int(input())

d = [0] * 1001 

# 다이나믹 프로그래밍(Dynamic Programming) 진행(보텀업)
d[1] = 1
d[2] = 3
for i in range(3, n + 1) :
    d[i] = (d[i - 1] + 2 * d[i - 2]) % 796796
    
# 계산된 결과 출력 
print(d[n])
# Out:
# 3
# 5

# %% [markdown]
# **해석**

# %% [markdown]
# *점화식*

# %% [markdown]
# $$a_i{}=a_{i-1}+a_{i-2}\times 2$$
