# %% [markdown]
# ### (2) 팀 결성

# %% [markdown]
# 학교에서 학생들에게 0번에서 N번까지의 번호를 부여했다. 처음에는 모든 학생이 서로 다른 팀으로 구분되어, 총 N + 1개의 팀이 존재한다. 이때 선생님은 '팀 합치기' 연산과 '같은 팀 여부 확인' 연산을 사용할 수 있다. <br>
#     </br>1. '팀 합치기' 연산은 두 팀을 합치는 연산이다.
#     <br>2. '같은 팀 여부 확인' 연산은 특정한 두 학생이 같은 팀에 속하는지를 확인하는 연산이다.</br>
#
# 선생님이 M개의 연산을 수행할 수 있을 때, '같은 팀 여부 확인' 연산에 대한 연산 결과를 출력하는 프로그램을 작성하시오.

# %% [markdown]
# **입력 조건**
# * **첫째 줄에 N,M**이 주어진다. M은 입력으로 주어지는 연산의 개수 (1 ≤ N, M ≤ 100,000)
# * 다음 M개의 줄에는 각각의 연산이 주어진다.
# * '팀 합치기' 연산은 0 a b 형태로 주어진다. 이는 a번 학생이 속한 팀과 b번 학생이 속한 팀을 합친다는 의미
# * '같은 팀 여부 확인' 연산은 1 a b 형태로 주어진다. 이는 a번 학생과 b번 학생이 같은 팀에 속해 있는지를 확인하는 연산이다.
# * a와 b는 N 이하의 양의 정수이다.

# %% [markdown]
# **출력 조건**
# * '같은 팀 여부 확인' 연산에 대하여 한 줄에 하나씩 YES 혹은 NO로 결과를 출력한다.

# %%
# 서로소 집합
# 특정 원소가 속한 집합을 찾기
def find_parent(parent, x):
    # 루트 노드를 찾을 때까지 재귀 호출
    if parent[x] != x:
        parent[x] = find_parent(parent, parent[x])
    return parent[x]

# 두 원소가 속한 집합을 합치기
def union_parent(parent, a, b):
    a = find_parent(parent, a)
    b = find_parent(parent, b)
    if a < b:
        parent[b] = a
    else:
        parent[a] = b
        
# 노드의 개수와 간선(Union 연산)의 개수 입력 받기        
N, M = map(int, input().split())
parent = [0] * (N + 1) # 부모 테이블 초기화하기 

# 부모 테이블상에서, 부모를 자기 자신으로 초기화 
for i in range(N + 1):
    parent[i] = i

# 모든 간선에 대한 정보를 입력 받기
for _ in range(M):
    # operation : 연산의 종류,  a, b  : 학생들의 번호 
    operation, a, b = map(int, input().split())
    if operation == 0:  # '팀 합치기' 연산 
        # a와 b를 같은팀으로 합치기
        union_parent(parent, a, b)
    elif operation == 1:  # '같은 팀 여부 확인' 연산
        # a가 b랑 같은 팀에 있니?
        if find_parent(parent, a) == find_parent(parent, b):
            print("YES")
        else:
            print("NO")
# 입력 예시가 너무 이상하지 않아여...? 제가 문제를 이해를 못 한건지.....
# Out:
# 7 8
# 0 1 3
# 1 1 7
# NO
# 0 7 6
# 1 7 1
# NO
# 0 3 7
# 0 4 2
# 0 1 1
# 1 1 1
# YES

# %% [markdown]
# ![CH10.jpg](attachment:CH10.jpg)
