# %% [markdown]
# https://www.acmicpc.net/problem/14501

# %% [markdown]
# 오늘부터 N + 1 일째 되는 날 퇴사를 하기 위해, 남은 N일 동안 최대한 많은 상담을 하려고 한다. 백준이는 비서에게 최대한 많은 상담을 잡으라고 부탁을 했고, 비서는 하루에 하나씩 서로 다른 사람의 상담을 잡아 놓았다.
#
# 각각의 상담은 상담을 완료하는 데 걸리는 기간 T_i와 상담을 했을 때 받을 수 있는 금액 P_i로 이루어져 있다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1일에 잡혀 있는 상담은 총 3일이 걸리며, 상담했을 때 받을 수 있는 금액은 10이다. 5일에 잡혀있는 상담은 총 2일이 걸리며, 받을 수 있는 금액은 15이다.
#
# 상담하는 데 필요한 기간은 1일보다 클 수 있기에 모든 상담을 할 수는 없다. 예를 들어 1일에 상담을 하게 되면, 2, 3일에 있는 상담은 할 수 없다. 2일에 있는 상담을 하게 되면, 3, 4, 5, 6일에 잡혀 있는 상담은 할 수 없다.
#
# 또한 N + 1일째에는 회사에 없기에, 6, 7일에 있는 상담을 할 수 없다.
#
# 퇴사 전에 할 수 있는 상담의 최대 이익은 1일, 4일, 5일에 있는 상담을 하는 것이며, 이때의 이익은 10 + 20 + 15 = 45이다.
#
# 상담을 적절히 했을 때, 백준이가 얻을 수 있는 최대 수익을 구하는 프로그램을 작성해라.

# %% [markdown]
# 입력 조건 )
# - 첫째 줄에 N (1 <= N <= 15)이 주어진다.
# - 둘째 줄부터 N개의 줄에 T_i와 P_i가 공백으로 구분되어서 주어지며, 1일부터 N일까지 순서대로 주어진다. (1 <= T_i <= 5, 1 <= P_i <= 1000)
#
# 출력 조건 )
# - 첫째 줄에 백준이가 얻을 수 있는 최대 이익을 출력한다.

# %%
n = int(input())
data = []
for _ in range(n) :
    t, p = map(int, input().split())
    data.append([t, p])
# Out:
# 7
# 3 10
# 5 20
# 1 10
# 1 20
# 2 15
# 4 40
# 2 200

# %%
max_value = 0

for i in range(n-1, -1, -1) :
    time = data[i][0] + i 
    
    if time <= n :
        data[i][1] = max(data[i][1]+data[time][1], max_value)
        max_value = data[i][1]
    
    else :
        data[i][1] = max_value  # 0

# %%
print(max_value)
# Out:
# 45

# %%
data
# Out:
# [[3, 45], [5, 45], [1, 45], [1, 35], [2, 15], [4, 0], [2, 0]]

# %%
n = int(input())
data = []
for _ in range(n) :
    t, p = map(int, input().split())
    data.append([t, p])
data.append([0,0])
    
max_value = 0

for i in range(n-1, -1, -1) :
    time = data[i][0] + i 
    
    if time <= n :
        data[i][1] = max(data[i][1]+data[time][1], max_value)
        max_value = data[i][1]
    
    else :
        data[i][1] = max_value  # 0

#print(data)
print(max_value)
# Out:
# 10
# 5 50
# 4 40
# 3 30
# 2 20
# 1 10
# 1 10
# 2 20
# 3 30
# 4 40
# 5 50
# [[5, 90], [4, 80], [3, 70], [2, 60], [1, 50], [1, 40], [2, 30], [3, 30], [4, 0], [5, 0], [0, 0]]
# 90
